# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "http://www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&dispCtgrNo=1001574"
headers = {"accept-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"}

# %%
res = requests.get(url, headers=headers)

# %%
res
# Out:
# <Response [200]>

# %%
html = bs(res.text, "lxml" )

# %%
html
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="ko">
# <head>
# <title>11번가 베스트 - 11번가</title>
# <meta content="Upgrade Your Life - 11번가" name="description"/>
# <meta content="Upgrade Your Life - 11번가" name="keywords"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script src="//c.011st.com/html/experiment/experimentMetaInfo.js" type="text/javascript"></script>
# <script src="//c.011st.com/js/plab/plab-weblib.min.js?201805241100" type="text/javascript"></script>
# <script>
#
#     var plabPageKey = '/11st_best/category';
#     try{
#
#         var params = {
#             projectKey : "11st_web",
#             domain : "11st.co.kr"
#         };
#         plab.initBy(params, experimentMetaInfo);
#
#     }catch (e) { console.log(e) };
#
#
# </script>
# <script type="text/javascript">
#
# 	// Global Var
# ...

# %%
links = html.select(".product_conts")

# %%
# 쉣 
len(links)
# Out:
# 0
